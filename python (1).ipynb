# %%
list
# Out:
# list

# %%
l = [1,3,9]

# %%
for i in l :
  print(i*i)
# Out:
# 1
# 9
# 81

# %%
l1 = [1,2,3,4,45,5]
l2 = []
for i in l :
  l2 .append(i**2)

# %%
l2
# Out:
# [1, 9, 81]

# %%
[ i for i in l1 if i%2 == 0]
# Out:
# [2, 4]

# %%
l3 = ["sudha","skill","kumar","data science"]

# %%
[i. upper() for i in l3]
# Out:
# ['SUDHA', 'SKILL', 'KUMAR', 'DATA SCIENCE']

# %%
[i.lower() for i in l3]
# Out:
# ['sudha', 'skill', 'kumar', 'data science']

# %%
dict = {"name":"manvi"}

# %%
[i.upper() for i in dict]
# Out:
# ['NAME']

# %%
l1
# Out:
# [1, 2, 3, 4, 45, 5]

# %%
list(i**2 for i in l1)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
d ={"key1": 1 , "key" : 2 ,"key": 3 ,"key4" : 4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'key': 9, 'key4': 16}

# %%
{k:v*2 for k , v in d. items()}
# Out:
# {'key1': 2, 'key': 6, 'key4': 8}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key': 3, 'key4': 4}

# %%
def test1():
    print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
test1() + "sudh"
# Out:
# this is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/3118336650.py in <cell line: 0>()
# ----> 1 test1() + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my very first function"

# %%
test2()
# Out:
# 'this is my very first function'

# %%
test2()+"Sudh"
# Out:
# 'this is my very first functionSudh'

# %%
test2()
# Out:
# 'this is my very first function'

# %%
def test3():
        return "sudh",23,365.56,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 365.56, [1, 2, 3, 3])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 365.56

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
a = 1
b = 4

# %%
def test4():
  a = 5+6/7
  return a

# %%
a
# Out:
# 1

# %%
def test5(a,b,c):
  d = a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
def test6(a,b):
    return a+b

# %%
test6(56,76)
# Out:
# 132

# %%
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
def test7(*args):
  return args + [1,2,3,4]

# %%
test7[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/3029245508.py in <cell line: 0>()
# ----> 1 test7[1,2,3]
#
# TypeError: 'function' object is not subscriptable

# %%
type(test7())
# Out:
# tuple

# %%
test7(1,2,3)
# Out:
# (1, 2, 3)

# %%
test7(1,2,3,"sudh","kumar",[1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/1135636343.py in <cell line: 0>()
# ----> 1 test7(1,2,3,"sudh","kumar",[1,2,3,4])
#
# /tmp/ipykernel_696/3264949088.py in test7(*args)
#       1 def test7(*args):
# ----> 2   return args + [1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test8(*kwargs):
   return kwargs + [1,2,3,4]

# %%
test8(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/3990954993.py in <cell line: 0>()
# ----> 1 test8(1,2,3)
#
# /tmp/ipykernel_696/1256776290.py in test8(*kwargs)
#       1 def test8(*kwargs):
# ----> 2    return kwargs + [1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
type(test8())
# Out:
# tuple

# %%
def test12(*sudh):
  return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args,a):
  return args , a

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def tect14(c,d,a=23,b=1):
  return a,b,c,d

# %%
tect14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/1698530354.py in <cell line: 0>()
# ----> 1 tect14()
#
# TypeError: tect14() missing 2 required positional arguments: 'c' and 'd'

# %%
tect14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
tect14(2,5, a = 2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
  return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a = [1,2,3,4],b="sudh",c = 23.4)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.4}

# %%
def add(num1, num2):
    return num1 + num2

def subtract(num1, num2):
    return num1 - num2
