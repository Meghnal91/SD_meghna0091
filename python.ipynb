# %%
list
# Out:
# list

# %%
l = [1,23,456,"muskan" ,True,5+8j,458.23]

# %%
l[5].real
# Out:
# 5.0

# %%
l[0:5:2]
# Out:
# [1, 456, True]

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
type[l]
# Out:
# type[[1, 23, 456, 'muskan', True, (5+8j), 458.23]]

# %%
l[-1:-5:-2]
# Out:
# [458.23, True]

# %%
l
# Out:
# [1, 23, 456, 'muskan', True, (5+8j), 458.23]

# %%
s="maritimeexpertise"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_549/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['m',
#  'a',
#  'r',
#  'i',
#  't',
#  'i',
#  'm',
#  'e',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  't',
#  'i',
#  's',
#  'e',
#  1,
#  23,
#  456,
#  'muskan',
#  True,
#  (5+8j),
#  458.23]

# %%
l
# Out:
# [1, 23, 456, 'muskan', True, (5+8j), 458.23]

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'mu'

# %%
l[4]
# Out:
# True

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_549/1835283299.py in <cell line: 0>()
# ----> 1 l+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1=[3,4,5]

# %%
l1+l
# Out:
# [3, 4, 5, 1, 23, 456, 'muskan', True, (5+8j), 458.23]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
len(l)
# Out:
# 7

# %%
l.append(s)

# %%
s
# Out:
# 'maritimeexpertise'

# %%
l.append(l1)

# %%
l
# Out:
# [1, 23, 456, 'muskan', True, (5+8j), 458.23, 'maritimeexpertise', [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_549/2311825727.py in <cell line: 0>()
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  23,
#  456,
#  'muskan',
#  True,
#  (5+8j),
#  458.23,
#  'maritimeexpertise',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 5]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45, 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4]

# %%
l1.append(4)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 4]

# %%
l1.reverse()

# %%
l1
# Out:
# [4, 4, [2, 3, 4], [2, 3, 4], 'sudh', 3]

# %%
l2=[17,18,34,34,24]

# %%
l2.sort()

# %%
l2
# Out:
# [17, 18, 24, 34, 34]

# %%
l4=["kushi" ,"mehek","tanu","janvi"]

# %%
l4.index("tanu")
# Out:
# 2

# %%
tuple
# Out:
# [2, 3, 4, 56, 89, 'sudh', 45.65, False, (45+457j), [3, 4, 5]]

# %%
t = [2,3,4,5,"sudh",45.65,False,(45+457j),[3,4,5]]

# %%
type(t)
# Out:
# list

# %%
t.pop()
# Out:
# [3, 4, 5]

# %%
t.count

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"sudh",45+45j,34.465,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
s4={2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
s4.pop()
# Out:
# 1

# %%
s4
# Out:
# {2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6 = [2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3,"Sudh","sudh"]

# %%
l6 = list(set(l6))

# %%
l6
# Out:
# [1, 2, 3, 4, 5, 6, 'Sudh', 'sudh']

# %%
s5={234,45,23,12,567,45,2,789,234,"abc"}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 4, 45, 567, 789, 'abc'}

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 ={"key" : "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2 = {"name","sudhanshu","roll nunmder","93","number",334675}

# %%
d2
# Out:
# {334675, '93', 'name', 'number', 'roll nunmder', 'sudhanshu'}

# %%
d3 = {234:"sudh","_wer":"kumar",True:2345}

# %%
d3
# Out:
# {234: 'sudh', '_wer': 'kumar', True: 2345}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 2345

# %%
d3[1]
# Out:
# 2345

# %%
l = [1,2,3,4,4,"sudh","kmumar",324,34.456,"abc"]

# %%
l1_num = []
l2_str = []
for i in l:
    if type(i) == int or type(i) == float:
        l1_num.append(i)
    else:
        l2_str.append(i)

# %%
l1_num
# Out:
# [1, 2, 3, 4, 4, 324, 34.456]

# %%
l2_str
# Out:
# ['sudh', 'kmumar', 'abc']

# %%
l3 = [1,2,2,34,56,"sudh","subh",765,45.78,"rty"]

# %%
l3
# Out:
# [1, 2, 2, 34, 56, 'sudh', 'subh', 765, 45.78, 'rty']

# %%
l4_num = []
l5_str = []
l6_float = []
for i in l3:
    if type(i) == int or type(i) == float:
        l4_num.append(i)
    elif type(i) == str:
        l5_str.append(i)

# %%
l4_num
# Out:
# [1, 2, 2, 34, 56, 765, 45.78]

# %%
l5_str
# Out:
# ['sudh', 'subh', 'rty']

# %%
x =input()
if x == (x[::-1]):
    print("palindrome")
else:
    print("not palindrone")
# Out:
# 121
# palindrome

# %%
l = [1,2,3,4,5,6,7,8,9,45,6,7]

# %%
l.index(45)
# Out:
# 9

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 45, 6, 7]

# %%
total_sum = sum(l)

# %%
l = [2,3,3,9,7,11,13,12]

# %%
list(set(l))
# Out:
# [2, 3, 7, 9, 11, 12, 13]

# %%
d2 = {"name":"janvi","class":"nine"}

# %%
keys = []
values = []
for item in d2.items():
    keys.append(item[0])
    values.append(item[1])
print(keys)
print(values)
# Out:
# ['name', 'class']
# ['janvi', 'nine']

# %%
dict1 = {"a":"akshat","b":"bhuvan","c":"chandan"}

# %%
keys = []
values = []
for item in dict1.items():
    keys.append(item[0])
    values.append(item[1])
print(keys)
print(values)
# Out:
# ['a', 'b', 'c']
# ['akshat', 'bhuvan', 'chandan']
