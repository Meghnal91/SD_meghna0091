# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
x =10

# %%
x
10
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
a = 5
b = 6
a+b
# Out:
# 11

# %%
a = 5
b = 8
a*b
# Out:
# 40

# %%
a = 8
b = 2
a-b
# Out:
# 6

# %%
a = 40
b = 5
a/b
# Out:
# 8.0

# %%
x = 10

# %%
y = 20

# %%
x+y
# Out:
# 30

# %%
type(x)
# Out:
# int

# %%
b = 20.9

# %%
type(b)
# Out:
# float

# %%
g ="meghna"

# %%
type(g)
# Out:
# str

# %%
e =  "this is my first tech class"

# %%
type(e)
# Out:
# str

# %%
n = True

# %%
n/2
# Out:
# 0.5

# %%
True+True
# Out:
# 2

# %%
True*True
# Out:
# 1

# %%
True/True
# Out:
# 1.0

# %%
list
# Out:
# list

# %%
l = [1,345,45,"megha",True,5+7j,345.66]

# %%
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345.66]

# %%
type(l)
# Out:
# list

# %%
l[0:5]
# Out:
# [1, 345, 45, 'megha', True]

# %%
l[0:5:2]
# Out:
# [1, 45, True]

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
l
# Out:
# [1, 345, 45, 'megha', True, (5+7j), 345.66]

# %%
l[-1]
# Out:
# 345.66

# %%
l
# Out:
# [1, 345, 45, 'megha', True, (5+7j), 345.66]

# %%
l[-1:-5:-2]
# Out:
# [345.66, True]

# %%
l[1:6:-2]
# Out:
# []

# %%
l[-1:-8:-6]
# Out:
# [345.66, 1]

# %%
l.append(6)

# %%
print(l)
# Out:
# [1, 345, 45, 'megha', True, (5+7j), 345.66, 6]

# %%
s="neha"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2257/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['n', 'e', 'h', 'a', 1, 345, 45, 'megha', True, (5+7j), 345.66, 6]
